# %%
#importing the libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
#Examining the link
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = urlopen(url).read().decode('utf-8')
soup = BeautifulSoup(page, 'html.parser')
wiki_table = soup.body.table.tbody

# %%
#forming a data frame
def get_cell(element):
    cells = element.find_all('td')
    row = []
    
    for cell in cells:
        if cell.a:            
            if (cell.a.text):
                row.append(cell.a.text)
                continue
        row.append(cell.string.strip())
        
    return row

# %%
def get_row():    
    data = []  
    
    for tr in wiki_table.find_all('tr'):
        row = get_cell(tr)
        if len(row) != 3:
            continue
        data.append(row)        
    
    return data

# %%
data = get_row()
columns = ['PostalCode', 'Borough', 'Neighbourhood']
df = pd.DataFrame(data, columns=columns)
df.head()
# Out:
#   PostalCode           Borough              Neighbourhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
#deleting the rows with borough as not assigned
df1 = df[df.Borough != 'Not assigned']
df1 = df1.sort_values(by=['PostalCode','Borough'])

df1.reset_index(inplace=True)
df1.drop('index',axis=1,inplace=True)

df1.head()
# Out:
#   PostalCode      Borough                           Neighbourhood
# 0        M1B  Scarborough                          Malvern, Rouge
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
df_postcodes = df1['PostalCode']
df_postcodes.drop_duplicates(inplace=True)
df2 = pd.DataFrame(df_postcodes)
df2['Borough'] = '';
df2['Neighbourhood'] = '';


df2.reset_index(inplace=True)
df2.drop('index', axis=1, inplace=True)
df1.reset_index(inplace=True)
df1.drop('index', axis=1, inplace=True)

for i in df2.index:
    for j in df1.index:
        if df2.iloc[i, 0] == df1.iloc[j, 0]:
            df2.iloc[i, 1] = df1.iloc[j, 1]
            df2.iloc[i, 2] = df2.iloc[i, 2] + ',' + df1.iloc[j, 2]
            
for i in df2.index:
    s = df2.iloc[i, 2]
    if s[0] == ',':
        s =s [1:]
    df2.iloc[i,2 ] = s

# %%
#importing the required libraries for adding geographical coordinates
! pip install geopy

# %%
from geopy.geocoders import Nominatim

# %%
#adding the geographical coordinates to the data
df2['Latitude'] = '0';
df2['Longitude'] = '0';

df3 = pd.read_csv('Geospatial_Coordinates.csv')
df3.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
for i in df2.index:
    for j in df3.index:
        if df2.iloc[i, 0] == df3.iloc[j, 0]:
            df2.iloc[i, 3] = df3.iloc[j, 1]
            df2.iloc[i, 4] = df3.iloc[j, 2]
            
df2.head()
# Out:
#   PostalCode      Borough                           Neighbourhood Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.8067
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.7845
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.7636
# 3        M1G  Scarborough                                  Woburn   43.771
# 4        M1H  Scarborough                               Cedarbrae  43.7731
#
#   Longitude
# 0  -79.1944
# 1  -79.1605
# 2  -79.1887
# 3  -79.2169
# 4  -79.2395

# %%
#clustering the neighbourhoods in toronto
df4 = df2.copy()
df4 = df4[df2.Borough.str.contains("Toronto")]
df4.head()
# Out:
#    PostalCode          Borough                   Neighbourhood Latitude  \
# 37        M4E     East Toronto                     The Beaches  43.6764
# 41        M4K     East Toronto    The Danforth West, Riverdale  43.6796
# 42        M4L     East Toronto  India Bazaar, The Beaches West   43.669
# 43        M4M     East Toronto                 Studio District  43.6595
# 44        M4N  Central Toronto                   Lawrence Park   43.728
#
#    Longitude
# 37   -79.293
# 41  -79.3522
# 42  -79.3156
# 43  -79.3409
# 44  -79.3888

# %%
! pip install folium
import folium
from sklearn.cluster import KMeans

# %%
toronto_map = folium.Map(location=[43.65, -79.4], zoom_start=12)

X = df4['Latitude']
Y = df4['Longitude']
Z = np.stack((X, Y), axis=1)

kmeans = KMeans(n_clusters=4, random_state=0).fit(Z)

clusters = kmeans.labels_
colors = ['red', 'green', 'blue', 'yellow']
df4['Cluster'] = clusters

for latitude, longitude, borough, cluster in zip(df4['Latitude'], df4['Longitude'], df4['Borough'], df4['Cluster']):
    label = folium.Popup(borough, parse_html=True)
    folium.CircleMarker(
        [latitude, longitude],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color=colors[cluster],
        fill_opacity=0.7).add_to(toronto_map)  

toronto_maptoronto_map = folium.Map(location=[43.65, -79.4], zoom_start=12)

X = df4['Latitude']
Y = df4['Longitude']
Z = np.stack((X, Y), axis=1)

kmeans = KMeans(n_clusters=4, random_state=0).fit(Z)

clusters = kmeans.labels_
colors = ['red', 'green', 'blue', 'yellow']
df4['Cluster'] = clusters

for latitude, longitude, borough, cluster in zip(df4['Latitude'], df4['Longitude'], df4['Borough'], df4['Cluster']):
    label = folium.Popup(borough, parse_html=True)
    folium.CircleMarker(
        [latitude, longitude],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color=colors[cluster],
        fill_opacity=0.7).add_to(toronto_map)  

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
